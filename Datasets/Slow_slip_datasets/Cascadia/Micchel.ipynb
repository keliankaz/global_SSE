# %%
import pandas as pd
import numpy as np

# %%
# read in the data
data = pd.read_csv('Michel2019.csv', header=0)

# %%
data
# Out:
#           Lat_SSE     Time_SSE  Mo_rate_SSE
# 0       47.588232  2015.912404     0.000354
# 1       41.324077  2014.606449     0.001253
# 2       47.059558  2015.906929     0.001457
# 3       48.679842  2017.169078     0.001991
# 4       45.310346  2011.408640     0.002211
# ...           ...          ...          ...
# 213313  48.227227  2007.085573   182.836499
# 213314  48.174700  2007.080098   182.929777
# 213315  48.227227  2007.077360   183.521643
# 213316  48.227227  2007.082836   183.732507
# 213317  48.227227  2007.080098   183.956145
#
# [213318 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(20,3),dpi=300)
ax.scatter(data['Time_SSE'], data['Lat_SSE'], c=data['Mo_rate_SSE'],s=0.1)
